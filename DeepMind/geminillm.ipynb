# %%
#pip install -q -U google-generativeai

# %%
import os 
os.environ['GOOGLE_API_KEY'] = "AQ.Ab8RN6JemeZ50qNZ8dhky_-5G_drtmPrtY1kxEhkX_RiN88NHw"

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])
# Out:
# C:\Users\nupri\AppData\Local\Temp\ipykernel_35080\3684644085.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
#model = genai.GenerativeModel('models/gemini-3-flash-preview')
#model = genai.GenerativeModel('models/gemini-3.1-flash-lite')

# %%
response = model.generate_content(
    "Generate a table comparing ML, AI, GenAI, Agentic AI, and RAG."
)

print(response.text)
# Out:
# It's easy to get these terms intertwined as they are deeply related. Here's a table to clarify their distinctions and relationships:
#
# ## Comparing AI, ML, GenAI, Agentic AI, and RAG
#
# | Feature                | Artificial Intelligence (AI)                     | Machine Learning (ML)                             | Generative AI (GenAI)                                | Agentic AI                                                   | Retrieval-Augmented Generation (RAG)                                      |
# | :--------------------- | :----------------------------------------------- | :------------------------------------------------ | :--------------------------------------------------- | :----------------------------------------------------------- | :------------------------------------------------------------------------ |
# ...

# %%
response = model.generate_content('generate table about ml vs ai vs genai vs agentic ai vs rag')
print(response.text)
# Out:
# Here's a table comparing ML, AI, GenAI, Agentic AI, and RAG, highlighting their relationships and distinct characteristics:
#
# ---
#
# ## AI vs. ML vs. GenAI vs. Agentic AI vs. RAG: A Comparative Table
#
# | Feature          | **AI (Artificial Intelligence)**                                    | **ML (Machine Learning)**                                                     | **GenAI (Generative AI)**                                                 | **Agentic AI (AI Agents)**                                               | **RAG (Retrieval-Augmented Generation)**                                  |
# ...

# %% [markdown]
# # MULTIMODEL --> IMAGE TO TEXT GENERATION MODEL

# %%
import pathlib
import textwrap 
import google.generativeai as genai
from IPython.display import display, Markdown


def to_markdown(text):
    text = text.replace('*',' *') 
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True) )

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# ...

# %%
import PIL.Image # PYTHON IMAGEING LIBRARY 
img = PIL.Image.open(r'C:\Users\nupri\2026_INTERNSHIP\DeepMind\OIP.webp')
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=239x239>

# %%
model = genai.GenerativeModel('models/gemini-3.1-flash-lite')

# %%
response = model.generate_content(img) 
to_markdown(response.text)
# Out:
# >The image provided is a portrait of a young woman with dark brown hair and brown eyes, set against a background of soft, out-of-focus circular lights (bokeh).
# >
# >This image appears to be  * *AI-generated * *. There are several visual indicators common to AI imagery:
# >
# > *    * *Stylized Perfection: * * The skin texture is smoothed in a way that is typical of models like Stable Diffusion or Midjourney, often lacking natural skin irregularities or pores.
# > *    * *Symmetry and Lighting: * * The lighting is extremely consistent and idealized, characteristic of high-end AI art generation.
# > *    * *Watermark: * * There is a faint watermark in the bottom-right corner that reads "stablediffusionweb.com," which is a platform used to generate images using the Stable Diffusion AI model.
# >
# >In terms of image description, she is wearing a white or light-colored garment, has a neutral, composed expression, and features a classic, balanced facial structure.

# %%
import PIL.Image # PYTHON IMAGEING LIBRARY 
img1 = PIL.Image.open(r'C:\Users\nupri\2026_INTERNSHIP\DeepMind\OIP (1).webp')
img1
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=474x237>

# %%
response1 = model.generate_content(img1) 
to_markdown(response1.text)
# Out:
# >This image features four prominent American women who have served in the United States Congress. From left to right, they are:
# >
# > *    * *Rashida Tlaib: * * Representative for Michigan's 12th congressional district.
# > *    * *Ayanna Pressley: * * Representative for Massachusetts' 7th congressional district.
# > *    * *Cori Bush: * * Former Representative for Missouri's 1st congressional district.
# > *    * *Ilhan Omar: * * Representative for Minnesota's 5th congressional district.
# >
# >These four women, often referred to as part of a group known as "The Squad," were elected to the U.S. House of Representatives in 2018 and 2020. They are known for being part of the progressive wing of the Democratic Party.
