# %%
import sys
print(sys.executable)

from langchain_google_genai import ChatGoogleGenerativeAI

print("Success!")
# Out:
# c:\Users\nupri\2026_INTERNSHIP\.venv\Scripts\python.exe
# Success!

# %%
import os

# Set the API key (Note: avoid hardcoding sensitive keys in production)
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6JKCPf5eE3gaovGTZPyveX_W3n2G8mY8q-wCuPDhDyqhA"

# Import the correct class for using Gemini models via LangChain
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the model (use "gemini-1.5-flash" or "gemini-1.5-pro" – not "2.0-flash" as it doesn't exist)
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# Test the model
response = model.invoke("What's the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
model.invoke("About Generative AI and Agentic AI")
# Out:
# AIMessage(content='Generative AI and Agentic AI are two distinct but increasingly complementary paradigms within the field of artificial intelligence. Understanding their differences and how they can work together is key to grasping the future of AI.\n\n---\n\n## 1. Generative AI\n\n**What it is:** Generative AI refers to AI models capable of producing novel, original content (text, images, audio, video, code, etc.) that resembles the data they were trained on, but isn\'t an exact copy.\n\n**Core Function:** To **create** or **synthesize** new information based on learned patterns and structures.\n\n**Key Characteristics:**\n*   **Creation:** Generates new data from scratch based on a prompt or input.\n*   **Pattern Recognition & Replication:** Learns complex patterns, styles, and relationships from vast datasets.\n*   **Content Focus:** Its primary output is a piece of content (a story, an image, a song, a piece of code).\n*   **No Intrinsic Goal/Action:** It doesn\'t inherently have a goal to achieve in the world beyond generating its output. It responds to a prompt.\n*   **Examples:**\n    *   **Large Language Models (LLMs) like ChatGPT, Bard, Llama:** Generate human-like text, answer questions, write essays, summarize documents, translate languages.\n    *   **Image Generators like DALL-E, Midjourney, Stable Diffusion:** Create images from text descriptions.\n    *   **Music Generators:** Compose original music.\n    *   **Code Generators:** Write or complete programming code.\n    *   **Video Generators:** Produce short video clips from text or image inputs.\n\n**Analogy:** Think of a highly skilled artist, writer, or composer who can produce amazing works on demand. You tell them *what* to create, and they create it. They don\'t decide *why* it needs to be created or *what to do with it* after it\'s done.\n\n---\n\n## 2. Agentic AI (AI Agents)\n\n**What it is:** Agentic AI, or AI agents, refers to AI systems designed to autonomously perceive their environment, reason about their goals, plan a sequence of actions, execute those actions, and reflect on the outcomes to achieve a specific objective. They are goal-oriented and proactive.\n\n**Core Function:** To **act** and **achieve** a defined goal in an environment, often involving multiple steps and interactions.\n\n**Key Characteristics:**\n*   **Autonomy:** Can operate independently to pursue a goal without constant human intervention.\n*   **Goal-Oriented:** Designed to accomplish a specific objective (e.g., "book me a flight," "research competitive products," "build a website").\n*   **Perception:** Can gather information from its environment (e.g., reading web pages, interacting with APIs, monitoring system states).\n*   **Planning & Reasoning:** Breaks down complex goals into smaller, manageable sub-tasks and devises strategies to achieve them. This is often where Generative AI (LLMs) plays a crucial role.\n*   **Action Execution:** Can interact with the world through tools, APIs, software interfaces, or even physical robots.\n*   **Memory & Learning:** Can remember past interactions, learn from successes and failures, and adapt its behavior.\n*   **Reflection & Self-Correction:** Evaluates its progress, identifies errors, and adjusts its plan or actions accordingly.\n*   **Examples:**\n    *   **Autonomous Research Agents:** Given a topic, they search the web, synthesize information, and write a report.\n    *   **Personal Assistants:** Beyond just answering questions, they could manage your calendar, book appointments, order groceries, and handle email.\n    *   **Software Development Agents (e.g., Auto-GPT, BabyAGI):** Given a high-level goal (e.g., "create a simple web app for task management"), they write code, test it, debug it, and deploy it.\n    *   **Robotics:** AI controlling a robot to navigate a room, pick up objects, and perform tasks.\n    *   **Automated Customer Service Agents:** Not just answering FAQs, but actively troubleshooting issues, escalati ...
