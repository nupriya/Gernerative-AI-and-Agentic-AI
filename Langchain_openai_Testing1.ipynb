# %%
#pip install -U "langchain[openai]

# %%
import os
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"] = "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"

llm = ChatOpenAI(model="gpt-5")

response = llm.invoke("job opportunity in 2027")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 8
#       4 os.environ["OPENAI_API_KEY"] = "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"
#       5
#       6 llm = ChatOpenAI(model="gpt-5")
#       7
# ----> 8 response = llm.invoke("job opportunity in 2027")
#       9 print(response.content)
#
# File c:\Users\nupri\2026_INTERNSHIP\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
# ...
