# %% [markdown]
# # TOKENS 1 JUNE

# %%
import os
import nltk
#nltk.download()
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nupri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
AI = 'Naresh IT offers practical AI, Machine Learning, and Gen AI internships designed for both students and working professionals. These programs provide hands-on, real-world project experience with a focus on making participants job-ready.'

# %%
AI
# Out:
# 'Naresh IT offers practical AI, Machine Learning, and Gen AI internships designed for both students and working professionals. These programs provide hands-on, real-world project experience with a focus on making participants job-ready.'

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import sent_tokenize
sent_tokens = sent_tokenize(AI)
sent_tokens
# Out:
# ['Naresh IT offers practical AI, Machine Learning, and Gen AI internships designed for both students and working professionals.',
#  'These programs provide hands-on, real-world project experience with a focus on making participants job-ready.']

# %%
from nltk.tokenize import word_tokenize
word_tokens = word_tokenize(AI)
word_tokens
# Out:
# ['Naresh',
#  'IT',
#  'offers',
#  'practical',
#  'AI',
#  ',',
#  'Machine',
#  'Learning',
#  ',',
#  'and',
#  'Gen',
#  'AI',
#  'internships',
#  'designed',
#  'for',
#  'both',
#  'students',
#  'and',
#  'working',
#  'professionals',
#  '.',
#  'These',
#  'programs',
#  'provide',
#  'hands-on',
#  ',',
#  'real-world',
#  'project',
#  'experience',
#  'with',
#  'a',
#  'focus',
#  'on',
#  'making',
#  'participants',
#  'job-ready',
#  '.']

# %%
len(sent_tokens)
# Out:
# 2

# %%
len(word_tokens)
# Out:
# 37

# %% [markdown]
# # NGRAM
# # Unigram

# %%
from nltk.util import ngrams
unigrams = list(ngrams(word_tokens, 1))
print("Unigrams:")
print(unigrams)
# Out:
# Unigrams:
# [('Naresh',), ('IT',), ('offers',), ('practical',), ('AI',), (',',), ('Machine',), ('Learning',), (',',), ('and',), ('Gen',), ('AI',), ('internships',), ('designed',), ('for',), ('both',), ('students',), ('and',), ('working',), ('professionals',), ('.',), ('These',), ('programs',), ('provide',), ('hands-on',), (',',), ('real-world',), ('project',), ('experience',), ('with',), ('a',), ('focus',), ('on',), ('making',), ('participants',), ('job-ready',), ('.',)]

# %% [markdown]
# # Bigrams

# %%
bigrams = list(ngrams(word_tokens, 2))
print("\nBigrams:")
print(bigrams)
# Out:
# Bigrams:
# [('Naresh', 'IT'), ('IT', 'offers'), ('offers', 'practical'), ('practical', 'AI'), ('AI', ','), (',', 'Machine'), ('Machine', 'Learning'), ('Learning', ','), (',', 'and'), ('and', 'Gen'), ('Gen', 'AI'), ('AI', 'internships'), ('internships', 'designed'), ('designed', 'for'), ('for', 'both'), ('both', 'students'), ('students', 'and'), ('and', 'working'), ('working', 'professionals'), ('professionals', '.'), ('.', 'These'), ('These', 'programs'), ('programs', 'provide'), ('provide', 'hands-on'), ('hands-on', ','), (',', 'real-world'), ('real-world', 'project'), ('project', 'experience'), ('experience', 'with'), ('with', 'a'), ('a', 'focus'), ('focus', 'on'), ('on', 'making'), ('making', 'participants'), ('participants', 'job-ready'), ('job-ready', '.')]

# %% [markdown]
# # Trigrams

# %%
trigrams = list(ngrams(word_tokens, 3))
print("\nTrigrams:")
print(trigrams)
# Out:
# Trigrams:
# ...

# %% [markdown]
# # Everygrams

# %%
from nltk.util import everygrams

word_tokens = word_tokenize(AI)

for gram in everygrams(word_tokens, max_len=3):
    print(gram)
# Out:
# ('Naresh',)
# ('Naresh', 'IT')
# ('Naresh', 'IT', 'offers')
# ('IT',)
# ('IT', 'offers')
# ('IT', 'offers', 'practical')
# ('offers',)
# ('offers', 'practical')
# ('offers', 'practical', 'AI')
# ('practical',)
# ('practical', 'AI')
# ('practical', 'AI', ',')
# ('AI',)
# ('AI', ',')
# ('AI', ',', 'Machine')
# (',',)
# (',', 'Machine')
# (',', 'Machine', 'Learning')
# ('Machine',)
# ('Machine', 'Learning')
# ('Machine', 'Learning', ',')
# ('Learning',)
# ('Learning', ',')
# ('Learning', ',', 'and')
# (',',)
# (',', 'and')
# (',', 'and', 'Gen')
# ('and',)
# ('and', 'Gen')
# ('and', 'Gen', 'AI')
# ('Gen',)
# ('Gen', 'AI')
# ('Gen', 'AI', 'internships')
# ('AI',)
# ('AI', 'internships')
# ('AI', 'internships', 'designed')
# ('internships',)
# ('internships', 'designed')
# ('internships', 'designed', 'for')
# ('designed',)
# ('designed', 'for')
# ('designed', 'for', 'both')
# ('for',)
# ('for', 'both')
# ('for', 'both', 'students')
# ('both',)
# ('both', 'students')
# ...

# %%
paragraph =  """Before you can begin to determine what the composition of a particular paragraph will be,
             you must first decide on a working thesis for your paper. What is the most important idea
           that you are trying to convey to your reader? The information in each paragraph must be related
           to that idea. In other words, your paragraphs should remind your reader that there is a recurrent 
        relationship between your thesis and the information in each paragraph. A working thesis functions like
         a seed from which your paper, and your ideas, will grow. The whole process is an organic one—a natural
        progression from a seed to a full-blown paper where there are direct, familial relationships between all
        of the ideas in the paper.

        The decision about what to put into your paragraphs begins with the germination of a seed of ideas;
         this “germination process” is better known as brainstorming. There are many techniques for brainstorming;
         whichever one you choose, this stage of paragraph development cannot be skipped. Building paragraphs can
         be like building a skyscraper: there must be a well-planned foundation that supports what you are building.
         Any cracks, inconsistencies, or other corruptions of the foundation can cause your whole paper to crumble."""

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
ps = PorterStemmer()
wordnet = WordNetLemmatizer()
sentences = nltk.sent_tokenize(paragraph)
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
# create the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
x_bow = cv.fit_transform(corpus).toarray()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
x_tfidf = tfidf.fit_transform(corpus).toarray()
